# %% [markdown]
# <a href="https://colab.research.google.com/github/hemanthk97/AHRMS/blob/master/Data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib as mpl
import numpy as np

# %%
mpl.__version__
# Out:
# '3.2.1'

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # **Static 2D Plotting**

# %%
plt.style.use('seaborn')

# %%
mpl.rcParams['font.family'] = 'serif'

# %%
# %matplotlib inline

# %% [markdown]
# ## **One-Dimensional Data sets**

# %% [markdown]
# > The most fundamental, but the nevertheless quite powerful, plotting function is `plt.plot()`. In principle, it needs two sets of numbers:
#
# *x values*
#
# *   A **list** or **array** containing the *x coordinates*.
#
# *y values*
#
# *   A **list** or **array** containing the *y coordinates*.
#
#
# > The number of *x* and *y* values provided must match, of course.

# %%
np.random.seed(1000) # Fixes the seed for the random number generator for reproducibility

# %%
y = np.random.standard_normal(20)

# %%
x = np.arange(len(y))
plt.plot(x,y)

# %%
plt.plot(y) # There is no need to provide the extra infromation of x values. If one only provides the y values, plt.plot() takes the index values as the x values

# %% [markdown]
# ### **NumPy Arrays and matplotlib**

# %%
plt.plot(y.cumsum())

# %%
plt.plot(y.cumsum())
plt.grid(False)
plt.axis('equal')
# Out:
# (-0.9500000000000001, 19.95, -2.322818663749045, 0.5655085808655865)

# %% [markdown]
# > Options of plt.axis() are given below

# %% [markdown]
# |Parameter|Description|
# |--- |--- |
# |Empty|Returns current axis limits|
# |off|Turns axis lines and labels off|
# |equal|Leads to equal scaling|
# |scaled|Produces equal scaling via dimension changes|
# |tight|Makes all data visible (tightens limits)|
# |image|Makes all data visible (with data limits)|
# |[xmin, xmax, ymin, ymax]|Sets limits to given (list of) values|

# %% [markdown]
# > One can directly set the minimum and maximum values of each axis by using `plt.xlim()` and `plt.ylim()`

# %%
plt.plot(y.cumsum())
plt.xlim(-1,20)
plt.ylim(np.min(y.cumsum())-1,np.max(y.cumsum())+1)
# Out:
# (-3.1915310617211072, 1.4342209788376488)

# %% [markdown]
# > For the sake of better readability, a plot usually contains a number of labels, title and labels describing the nature of the x and y values. These are added by the functions `plt.title()`, `plt.xlabel()`, and `plt.ylabel()`, respectively. By default, `plot()` plots continuous lines, even if discrete data points are provided. The plotting of discrete points is accomplished by choosing a different style optio. overlays (red) points and (blue) line with line width of 1.5 points

# %%
plt.figure(figsize=(10,6))
plt.plot(y.cumsum(),'b',lw=1.5)
plt.plot(y.cumsum(), 'ro')
plt.xlabel('index')
plt.ylabel('values')
plt.title('A simple Plot')
# Out:
# Text(0.5, 1.0, 'A simple Plot')

# %% [markdown]
# > By default `plt.plot()` supports the color abbreviations
#
# |Character|Color|
# |--- |--- |
# |b|Blue|
# |g|Green|
# |r|Red|
# |c|Cyan|
# |m|Magenta|
# |y|Yellow|
# |k|Black|
# |w|White|
#
#
# > In terms of lines and/or point sytles `plt.plot()` supports characters listed below
#
#
# |Character|Symbol|
# |--- |--- |
# |-|Solid line style|
# |--|Dashed line style|
# |-.|Dash-dot line style|
# |:|Dotted line style|
# |.|Point marker|
# |,|Pixel marker|
# |o|Circle marker|
# |v|Triangle_down marker|
# |^|Triangle_up marker|
# |<|Triangle_left marker|
# |>|Triangle_right marker|
# |1|Tri_down marker|
# |2|Tri_up marker|
# |3|Tri_left marker|
# |4|Tri_right marker|
# |s|Square marker|
# |p|Pentagon marker|
# |*|Star marker|
# |h|Hexagon1 marker|
# |H|Hexagon2 marker|
# |+|Plus marker|
# |x|X marker|
# |D|Diamond marker|
# |d|Thin diamond marker|
# |||Vline marker|
# |_|Hline marker|

# %% [markdown]
# ## **Two-Dimensional Data sets**
